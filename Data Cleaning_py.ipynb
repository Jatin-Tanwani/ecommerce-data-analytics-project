# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
product = pd.read_csv("products.csv")
product.head()
# Out:
#    product_id           created_at                product_name
# 0           1  2012-03-19 08:00:00      The Original Mr. Fuzzy
# 1           2  2013-01-06 13:00:00       The Forever Love Bear
# 2           3  2013-12-12 09:00:00    The Birthday Sugar Panda
# 3           4  2014-02-05 10:00:00  The Hudson River Mini bear

# %%
product.shape
# Out:
# (4, 3)

# %%
product.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    4 non-null      int64
#  1   created_at    4 non-null      str
#  2   product_name  4 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 228.0 bytes

# %%
product.isnull().sum()
# Out:
# product_id      0
# created_at      0
# product_name    0
# dtype: int64

# %%
product.duplicated().sum()
# Out:
# np.int64(0)

# %%
product.describe()
# Out:
#        product_id
# count    4.000000
# mean     2.500000
# std      1.290994
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.250000
# max      4.000000

# %%
product["product_id"].nunique()
# Out:
# 4

# %%
product.groupby("product_id").count()
# Out:
#             created_at  product_name
# product_id
# 1                    1             1
# 2                    1             1
# 3                    1             1
# 4                    1             1

# %%
product["product_id"].value_counts().plot(kind="pie")
plt.show()

# %%
product["created_at"]=pd.to_datetime(product["created_at"])

# %%
product.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    4 non-null      int64
#  1   created_at    4 non-null      datetime64[us]
#  2   product_name  4 non-null      str
# dtypes: datetime64[us](1), int64(1), str(1)
# memory usage: 228.0 bytes

# %%
product.head()
# Out:
#    product_id          created_at                product_name
# 0           1 2012-03-19 08:00:00      The Original Mr. Fuzzy
# 1           2 2013-01-06 13:00:00       The Forever Love Bear
# 2           3 2013-12-12 09:00:00    The Birthday Sugar Panda
# 3           4 2014-02-05 10:00:00  The Hudson River Mini bear

# %%
product["created_at"].head()
# Out:
# 0   2012-03-19 08:00:00
# 1   2013-01-06 13:00:00
# 2   2013-12-12 09:00:00
# 3   2014-02-05 10:00:00
# Name: created_at, dtype: datetime64[us]

# %%
product.to_csv("clean_products.csv",index=False)

# %% [markdown]
# ## order file

# %%
order=pd.read_csv("orders.csv")
order.head(10)
# Out:
#    order_id           created_at  website_session_id  user_id  \
# 0         1  2012-03-19 10:42:46                  20       20
# 1         2  2012-03-19 19:27:37                 104      104
# 2         3  2012-03-20 06:44:45                 147      147
# 3         4  2012-03-20 09:41:45                 160      160
# 4         5  2012-03-20 11:28:15                 177      177
# 5         6  2012-03-20 16:12:47                 232      232
# 6         7  2012-03-20 17:03:41                 241      241
# 7         8  2012-03-20 23:35:27                 295      295
# 8         9  2012-03-21 02:35:01                 304      304
# 9        10  2012-03-21 06:45:58                 317      317
#
#    primary_product_id  items_purchased  price_usd  cogs_usd
# 0                   1                1      49.99     19.49
# 1                   1                1      49.99     19.49
# 2                   1                1      49.99     19.49
# ...

# %%
order.shape
# Out:
# (32313, 8)

# %%
order.describe()
# Out:
#            order_id  website_session_id        user_id  primary_product_id  \
# count  32313.000000        32313.000000   32313.000000        32313.000000
# mean   16157.000000       258292.288707  215691.622629            1.392474
# std     9328.103961       132427.649842  108402.203189            0.732277
# min        1.000000           20.000000      13.000000            1.000000
# 25%     8079.000000       144828.000000  124135.000000            1.000000
# 50%    16157.000000       263554.000000  221461.000000            1.000000
# 75%    24235.000000       374799.000000  310542.000000            2.000000
# max    32313.000000       472818.000000  394273.000000            4.000000
#
#        items_purchased     price_usd      cogs_usd
# count     32313.000000  32313.000000  32313.000000
# mean          1.238666     59.991636     22.355406
# std           0.426274     17.808771      6.238621
# min           1.000000     29.990000      9.490000
# ...

# %%
order.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32313 entries, 0 to 32312
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            32313 non-null  int64
#  1   created_at          32313 non-null  str
#  2   website_session_id  32313 non-null  int64
#  3   user_id             32313 non-null  int64
#  4   primary_product_id  32313 non-null  int64
#  5   items_purchased     32313 non-null  int64
#  6   price_usd           32313 non-null  float64
#  7   cogs_usd            32313 non-null  float64
# dtypes: float64(2), int64(5), str(1)
# memory usage: 2.0 MB

# %%
order.isnull().sum()
# Out:
# order_id              0
# created_at            0
# website_session_id    0
# user_id               0
# primary_product_id    0
# items_purchased       0
# price_usd             0
# cogs_usd              0
# dtype: int64

# %%
order.duplicated().sum()
# Out:
# np.int64(0)

# %%
order["order_id"].nunique()
# Out:
# 32313

# %%
order["created_at"]=pd.to_datetime(order["created_at"])

# %%
order["created_at"].head(10)
# Out:
# 0   2012-03-19 10:42:46
# 1   2012-03-19 19:27:37
# 2   2012-03-20 06:44:45
# 3   2012-03-20 09:41:45
# 4   2012-03-20 11:28:15
# 5   2012-03-20 16:12:47
# 6   2012-03-20 17:03:41
# 7   2012-03-20 23:35:27
# 8   2012-03-21 02:35:01
# 9   2012-03-21 06:45:58
# Name: created_at, dtype: datetime64[us]

# %%
order.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32313 entries, 0 to 32312
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            32313 non-null  int64
#  1   created_at          32313 non-null  datetime64[us]
#  2   website_session_id  32313 non-null  int64
#  3   user_id             32313 non-null  int64
#  4   primary_product_id  32313 non-null  int64
#  5   items_purchased     32313 non-null  int64
#  6   price_usd           32313 non-null  float64
#  7   cogs_usd            32313 non-null  float64
# dtypes: datetime64[us](1), float64(2), int64(5)
# memory usage: 2.0 MB

# %%
df=order["price_usd"]-order["cogs_usd"]
df
# Out:
# 0        30.5
# 1        30.5
# 2        30.5
# 3        30.5
# 4        30.5
#          ...
# 32308    30.5
# 32309    20.5
# 32310    58.0
# 32311    20.5
# 32312    30.5
# Length: 32313, dtype: float64

# %%
order["price_usd"].sum()
# Out:
# np.float64(1938509.75)

# %%
df
# Out:
# 0        30.5
# 1        30.5
# 2        30.5
# 3        30.5
# 4        30.5
#          ...
# 32308    30.5
# 32309    20.5
# 32310    58.0
# 32311    20.5
# 32312    30.5
# Length: 32313, dtype: float64

# %%
df.sum()
# Out:
# np.float64(1216139.5)

# %%
order.shape
# Out:
# (32313, 8)

# %%
order.to_csv("clean_orders.csv",index=False)

# %%
order["created_at"].dt.month.value_counts() #MONTHLY SALES
# Out:
# created_at
# 12    3867
# 2     3587
# 1     3470
# 11    3464
# 3     2765
# 10    2688
# 9     2340
# 8     2161
# 7     2059
# 5     2047
# 6     1972
# 4     1893
# Name: count, dtype: int64

# %% [markdown]
# ## order items

# %%
items=pd.read_csv("order_items.csv")
items.head(10)
# Out:
#    order_item_id           created_at  order_id  product_id  is_primary_item  \
# 0              1  2012-03-19 10:42:46         1           1                1
# 1              2  2012-03-19 19:27:37         2           1                1
# 2              3  2012-03-20 06:44:45         3           1                1
# 3              4  2012-03-20 09:41:45         4           1                1
# 4              5  2012-03-20 11:28:15         5           1                1
# 5              6  2012-03-20 16:12:47         6           1                1
# 6              7  2012-03-20 17:03:41         7           1                1
# 7              8  2012-03-20 23:35:27         8           1                1
# 8              9  2012-03-21 02:35:01         9           1                1
# 9             10  2012-03-21 06:45:58        10           1                1
#
#    price_usd  cogs_usd
# 0      49.99     19.49
# 1      49.99     19.49
# 2      49.99     19.49
# 3      49.99     19.49
# ...

# %%
items.shape
# Out:
# (40025, 7)

# %%
items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40025 entries, 0 to 40024
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_item_id    40025 non-null  int64
#  1   created_at       40025 non-null  str
#  2   order_id         40025 non-null  int64
#  3   product_id       40025 non-null  int64
#  4   is_primary_item  40025 non-null  int64
#  5   price_usd        40025 non-null  float64
#  6   cogs_usd         40025 non-null  float64
# dtypes: float64(2), int64(4), str(1)
# memory usage: 2.1 MB

# %%
items.isnull().sum()
# Out:
# order_item_id      0
# created_at         0
# order_id           0
# product_id         0
# is_primary_item    0
# price_usd          0
# cogs_usd           0
# dtype: int64

# %%
items.duplicated().sum()
# Out:
# np.int64(0)

# %%
items["created_at"]=pd.to_datetime(items["created_at"])

# %%
items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40025 entries, 0 to 40024
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_item_id    40025 non-null  int64
#  1   created_at       40025 non-null  datetime64[us]
#  2   order_id         40025 non-null  int64
#  3   product_id       40025 non-null  int64
#  4   is_primary_item  40025 non-null  int64
#  5   price_usd        40025 non-null  float64
#  6   cogs_usd         40025 non-null  float64
# dtypes: datetime64[us](1), float64(2), int64(4)
# memory usage: 2.1 MB

# %%
items.describe()
# Out:
#        order_item_id                  created_at      order_id    product_id  \
# count   40025.000000                       40025  40025.000000  40025.000000
# mean    20013.000000  2014-05-13 10:24:45.947732  17121.957502      1.770019
# min         1.000000         2012-03-19 10:42:46      1.000000      1.000000
# 25%     10007.000000         2013-12-25 23:27:19   9871.000000      1.000000
# 50%     20013.000000         2014-07-14 15:31:31  17490.000000      1.000000
# 75%     30019.000000         2014-12-01 16:41:10  24818.000000      2.000000
# max     40025.000000         2015-03-19 05:38:31  32313.000000      4.000000
# std     11554.366599                         NaN   9053.765867      1.085561
#
#        is_primary_item     price_usd      cogs_usd
# count     40025.000000  40025.000000  40025.000000
# mean          0.807320     48.432473     18.047976
# min           0.000000     29.990000      9.490000
# 25%           1.000000     49.990000     19.490000
# ...

# %%
items["product_id"].value_counts() ## best selling products
# Out:
# product_id
# 1    24226
# 2     5796
# 4     5018
# 3     4985
# Name: count, dtype: int64

# %%
order["created_at"].dt.month.value_counts().sort_index().plot(kind="bar")
plt.title("monthly order")
plt.grid()
plt.show()

# %%
items.to_csv("clean_order_items.csv",index=False)

# %%
## order_items_refunds



refund=pd.read_csv("order_item_refunds.csv")
refund.head()
# Out:
#    order_item_refund_id           created_at  order_item_id  order_id  \
# 0                     1  2012-04-06 11:32:43             57        57
# 1                     2  2012-04-13 01:09:43             74        74
# 2                     3  2012-04-15 07:03:48             71        71
# 3                     4  2012-04-17 20:00:37            118       118
# 4                     5  2012-04-22 20:53:49            116       116
#
#    refund_amount_usd
# 0              49.99
# 1              49.99
# 2              49.99
# 3              49.99
# 4              49.99

# %%
refund.shape
# Out:
# (1731, 5)

# %%
refund.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1731 entries, 0 to 1730
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_item_refund_id  1731 non-null   int64
#  1   created_at            1731 non-null   str
#  2   order_item_id         1731 non-null   int64
#  3   order_id              1731 non-null   int64
#  4   refund_amount_usd     1731 non-null   float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 67.7 KB

# %%
refund.isnull().sum()
# Out:
# order_item_refund_id    0
# created_at              0
# order_item_id           0
# order_id                0
# refund_amount_usd       0
# dtype: int64

# %%
refund.duplicated().sum()
# Out:
# np.int64(0)

# %%
refund["refund_amount_usd"].sum()
# Out:
# np.float64(85338.69)

# %%
refund["created_at"]=pd.to_datetime(refund["created_at"])

# %%
refund.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1731 entries, 0 to 1730
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_item_refund_id  1731 non-null   int64
#  1   created_at            1731 non-null   datetime64[us]
#  2   order_item_id         1731 non-null   int64
#  3   order_id              1731 non-null   int64
#  4   refund_amount_usd     1731 non-null   float64
# dtypes: datetime64[us](1), float64(1), int64(3)
# memory usage: 67.7 KB

# %%
refund.shape
# Out:
# (1731, 5)

# %%
refund.to_csv("clean_order_item_refunds.csv",index=False)

# %%
refund["order_id"].nunique() ## total refun order
# Out:
# 1723

# %%
refund["created_at"].dt.month.value_counts().sort_index() # monthly refund trend
# Out:
# created_at
# 1     157
# 2     151
# 3     148
# 4      85
# 5      87
# 6     108
# 7     136
# 8     146
# 9     282
# 10    103
# 11    123
# 12    205
# Name: count, dtype: int64

# %%
refund["refund_amount_usd"].mean()
# Out:
# np.float64(49.3002253032929)

# %%
merged=pd.merge(order,items,on="order_id",how="inner")
merged.head()
# Out:
#    order_id        created_at_x  website_session_id  user_id  \
# 0         1 2012-03-19 10:42:46                  20       20
# 1         2 2012-03-19 19:27:37                 104      104
# 2         3 2012-03-20 06:44:45                 147      147
# 3         4 2012-03-20 09:41:45                 160      160
# 4         5 2012-03-20 11:28:15                 177      177
#
#    primary_product_id  items_purchased  price_usd_x  cogs_usd_x  \
# 0                   1                1        49.99       19.49
# 1                   1                1        49.99       19.49
# 2                   1                1        49.99       19.49
# 3                   1                1        49.99       19.49
# 4                   1                1        49.99       19.49
#
#    order_item_id        created_at_y  product_id  is_primary_item  \
# 0              1 2012-03-19 10:42:46           1                1
# 1              2 2012-03-19 19:27:37           1                1
# ...

# %%
merged.shape
# Out:
# (40025, 14)

# %%
## website+pageview_id

web=pd.read_csv("website_pageviews.csv")
web.head()
# Out:
#    website_pageview_id           created_at  website_session_id pageview_url
# 0                    1  2012-03-19 08:04:16                   1        /home
# 1                    2  2012-03-19 08:16:49                   2        /home
# 2                    3  2012-03-19 08:26:55                   3        /home
# 3                    4  2012-03-19 08:37:33                   4        /home
# 4                    5  2012-03-19 09:00:55                   5        /home

# %%
web.shape
# Out:
# (1188124, 4)

# %%
web.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1188124 entries, 0 to 1188123
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   website_pageview_id  1188124 non-null  int64
#  1   created_at           1188124 non-null  datetime64[us]
#  2   website_session_id   1188124 non-null  int64
#  3   pageview_url         1188124 non-null  str
# dtypes: datetime64[us](1), int64(2), str(1)
# memory usage: 36.3 MB

# %%
web["created_at"]=pd.to_datetime(web["created_at"])

# %%
web["website_pageview_id"].nunique()
# Out:
# 1188124

# %%
web["pageview_url"].value_counts()
# Out:
# pageview_url
# /products                      261231
# /the-original-mr-fuzzy         162525
# /home                          137576
# /lander-2                      131170
# /cart                           94953
# /lander-3                       79000
# /lander-5                       68166
# /shipping                       64484
# /billing-2                      48441
# /lander-1                       47574
# /thank-you-for-your-order       32313
# /the-forever-love-bear          26033
# /the-birthday-sugar-panda       19046
# /lander-4                        9385
# /billing                         3617
# /the-hudson-river-mini-bear      2610
# Name: count, dtype: int64

# %%
web["website_session_id"].nunique()  ##kitna unique visitor aaye.
# Out:
# 472871

# %%
web.groupby("website_session_id").size().mean()  ## avg user kitne page dekh raha hai.
# Out:
# np.float64(2.5125753112371028)

# %%
web["created_at"].dt.date.value_counts() ## dailt traffic
# Out:
# created_at
# 2014-11-28    13663
# 2014-12-01    11844
# 2013-11-29     9629
# 2013-12-02     7357
# 2012-11-23     7300
#               ...
# 2012-05-05      102
# 2012-04-21       99
# 2012-05-06       97
# 2012-04-29       94
# 2012-04-28       58
# Name: count, Length: 1096, dtype: int64

# %%
web[web["pageview_url"]=="/home"]["website_session_id"].nunique()
# Out:
# 137576

# %%
web[web["pageview_url"]=="/products"]["website_session_id"].nunique()
# Out:
# 261231

# %%
web.groupby("website_session_id")["pageview_url"].count().sort_values(ascending=False)
# Out:
# website_session_id
# 20        7
# 95032     7
# 95059     7
# 95074     7
# 95073     7
#          ..
# 472839    1
# 472808    1
# 472810    1
# 59946     1
# 7         1
# Name: pageview_url, Length: 472871, dtype: int64

# %%
bounce=web.groupby("website_session_id").size()  ## kitna user sirf 1 page dekh ke website chhod gaye
bounce[bounce==1].count()
# Out:
# np.int64(211640)

# %%
web.to_csv("clean_website_pageviews.csv",index=False)

# %% [markdown]
# ## website_sessions_file

# %%
session=pd.read_csv("website_sessions.csv")
session.head(10)
# Out:
#    website_session_id           created_at  user_id  is_repeat_session  \
# 0                   1  2012-03-19 08:04:16        1                  0
# 1                   2  2012-03-19 08:16:49        2                  0
# 2                   3  2012-03-19 08:26:55        3                  0
# 3                   4  2012-03-19 08:37:33        4                  0
# 4                   5  2012-03-19 09:00:55        5                  0
# 5                   6  2012-03-19 09:05:46        6                  0
# 6                   7  2012-03-19 09:06:27        7                  0
# 7                   8  2012-03-19 09:17:17        8                  0
# 8                   9  2012-03-19 09:27:56        9                  0
# 9                  10  2012-03-19 09:35:37       10                  0
#
#   utm_source utm_campaign utm_content device_type             http_referer
# 0    gsearch     nonbrand      g_ad_1      mobile  https://www.gsearch.com
# ...

# %%
session.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 472871 entries, 0 to 472870
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   website_session_id  472871 non-null  int64
#  1   created_at          472871 non-null  datetime64[us]
#  2   user_id             472871 non-null  int64
#  3   is_repeat_session   472871 non-null  int64
#  4   utm_source          389543 non-null  str
#  5   utm_campaign        389543 non-null  str
#  6   utm_content         389543 non-null  str
#  7   device_type         472871 non-null  str
#  8   http_referer        432954 non-null  str
# dtypes: datetime64[us](1), int64(3), str(5)
# memory usage: 32.5 MB

# %%
session.shape
# Out:
# (472871, 9)

# %%
session["created_at"]=pd.to_datetime(session["created_at"])

# %%
session["website_session_id"].nunique()
# Out:
# 472871

# %%
session.duplicated().sum()
# Out:
# np.int64(0)

# %%
session.describe()
# Out:
#        website_session_id                  created_at        user_id  \
# count       472871.000000                      472871  472871.000000
# mean        236436.000000  2014-02-24 16:35:16.899334  198037.970163
# min              1.000000         2012-03-19 08:04:16       1.000000
# 25%         118218.500000         2013-08-08 21:57:36  101966.500000
# 50%         236436.000000         2014-04-25 13:23:33  199483.000000
# 75%         354653.500000  2014-11-03 05:30:38.500000  294433.000000
# max         472871.000000         2015-03-19 07:59:08  394318.000000
# std         136506.243908                         NaN  111992.997798
#
#        is_repeat_session
# count      472871.000000
# mean            0.166119
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
# std             0.372188

# %%
session["utm_campaign"].value_counts() ## sabse jayeda search kona se product hai
# Out:
# utm_campaign
# nonbrand            337615
# brand                41243
# desktop_targeted      5590
# pilot                 5095
# Name: count, dtype: int64

# %%
session["utm_source"].value_counts() ##traffic by source
# Out:
# utm_source
# gsearch       316035
# bsearch        62823
# socialbook     10685
# Name: count, dtype: int64

# %%
session["is_repeat_session"].value_counts()
# Out:
# is_repeat_session
# 0    394318
# 1     78553
# Name: count, dtype: int64

# %%
session.groupby("utm_campaign")["website_session_id"].count()
# Out:
# utm_campaign
# brand                41243
# desktop_targeted      5590
# nonbrand            337615
# pilot                 5095
# Name: website_session_id, dtype: int64

# %%
session.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 472871 entries, 0 to 472870
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   website_session_id  472871 non-null  int64
#  1   created_at          472871 non-null  datetime64[us]
#  2   user_id             472871 non-null  int64
#  3   is_repeat_session   472871 non-null  int64
#  4   utm_source          389543 non-null  str
#  5   utm_campaign        389543 non-null  str
#  6   utm_content         389543 non-null  str
#  7   device_type         472871 non-null  str
#  8   http_referer        432954 non-null  str
# dtypes: datetime64[us](1), int64(3), str(5)
# memory usage: 32.5 MB

# %%
session.to_csv("clean_website_sessions.csv",index=False)
